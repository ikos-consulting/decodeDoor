# %%
import os
import numpy as np
import pandas as pd
import bokeh
import seaborn as sns
import time, datetime
from datetime import datetime
from time import strftime
from time import gmtime

# %%
#Init Repo Data
Repo_data = "C:/Users/Consultant/Desktop/Decoded Data/AV/data"
listfile_data = os.listdir(Repo_data)

# %%
#Combine les fichier csv de Data en DataFrame - combined_data
os.chdir(Repo_data)
combined_data = pd.concat([pd.read_csv(f) for f in listfile_data ], ignore_index=True)

# %%
#Init Repo Metadata
Repo_meta = "C:/Users/Consultant/Desktop/Decoded Data/AV/metadata/"
listfile_meta = os.listdir(Repo_meta)

# %%
os.chdir(Repo_meta)
combined_meta = pd.concat([pd.read_csv(f) for f in listfile_meta ], ignore_index=True)

# %%
if(combined_meta.iloc[0][0] == combined_data.iloc[0][53]):
        data = pd.merge(combined_data, combined_meta, how='inner', on=['ID'])

# %%
e = data[data['ID'] == 'z5700015________zr_57_83015_____dcu4____________dcucbmdata______190415_092447']
m = e.iloc[4]['TimeStamp']
e.iloc[0]
# Out:
# TimeStamp                                                                                            0
# Sleepmode                                                                                            1
# Transition                                                                                           1
# LT-V-DVR est active                                                                                  0
# LT-V<2 est active                                                                                    1
# LT-AO1 est active                                                                                    1
# LT-AO2 est active                                                                                    1
# LT-Ads est active                                                                                    0
# LT-Acq est active                                                                                    0
# LT-CF est active                                                                                     0
# LT-CF2 est active                                                                                    0
# LT-IH-UFR est active                                                                                 0
# LT-IF est active                                                                                     0
# LT-W est active                                                                                      0
# LT-OC est active                                                                                     0
# Fin de course porte verrouillé activé                                                                0
# Fin de course porte fermé activé                                                                     0
# Fin de course 1 de condamnation porte activé                                                         0
# Fin de course 2 de condamnation porte activé                                                         0
# Fin de course CLA complétement fermé activé                                                          0
# Fin de course CLA fermé activé                                                                       0
# Fin de course CLA isolé activé                                                                       0
# Fin de course CLA 1 de condamnation activé                                                           0
# Fin de course CLA 2 de condamnation activé                                                           0
# BP d'ouverture int activé                                                                            0
# BP d'ouverture ext activé                                                                            0
# BP de dev d'urgence porte activé                                                                     0
# Carré de forçage en ouverture du CLA activé                                                          0
# Carré de forçage en fermeture du CLA activé                                                          0
# Poigné de dev d'urgence porte activé                                                                 0
#                                                                            ...
# Voyant de fermeture : Clignotant                                                                     0
# Voyant BP d'ouverture int : Clignotant                                                               0
# Voyant BP d'ouverture ext : Clignotant                                                               0
# Voyant BP de dev d'urgence : Clignotant                                                              0
# Présence d'un défaut                                                                                 1
# Code du défaut présent- Cf.Tableau des defauts                                          35184372088832
# Courant moteur de la porte                                                                           0
# Tension moteur de la porte                                                                           0
# Position moteur de la porte                                                                          0
# Courant moteur de la marche mobile                                                                   0
# Tension moteur de la marche mobile                                                                   0
# Position moteur de la marche mobile                                                                  0
# ID                                                   z5700015________zr_57_83015_____dcu4__________...
# Date Depart                                                         Monday, April 15, 2019 11:17:06 AM
# Unique serial number                                                                          ['\x00']
# Device instance indication enumeration in the car                                                    1
# Device type e.g   DCU= 85                                                                           85
# Customer Code for the current trip. Utf-8                                                        ['P']
# Previous station identifier                                                                    4344402
# Next station identifier                                                                        5064012
# Outside Air Temperature(en degré)                                                                  4.6
# Version du CBM                                                                                       1
# Nombre Octets Alloués pour les IOs                                                                  14
# Nombre Octets Alloués pour les Analogs                                                              12
# Nombre de Variables Echantillons                                                                    50
# Nombre de Variables Entêtes Specifiques                                                              7
# Taille de la zone de data (octet)                                                                 1962
# Nombre Enregistrements                                                                             183
# Temps de démarrage (s)                                                                      1555319826
# Temps entre deux échantillons (ms)                                                                  50
# Name: 13323, Length: 71, dtype: object

# %%
test = data[data["Présence d'un défaut"] != 0]
t = bin(test["Code du défaut présent- Cf.Tableau des defauts"].iloc[0])
len(t)
len('1000000000000000000000000000000000000000000000')
# Out:
# 46

# %%
len('1000000000000000000000000000000000000000000000')
# Out:
# 46

# %%
data.dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-6226a73926db> in <module>
# ----> 1 data.dtypes
#
# NameError: name 'data' is not defined

# %%
t = data
len(t['ID'].unique().tolist())
t = t[t.iloc[:]['ID'] == t.iloc[-1]['ID']]
t = t[['Transition','Courant moteur de la porte','Tension moteur de la porte','Position moteur de la porte','Courant moteur de la marche mobile', 'Tension moteur de la marche mobile', 'Position moteur de la marche mobile', 'ID','TimeStamp']]
#t.to_csv('test2.csv', index=False)
#t[t['Transition'] == 3]
t
# Out:
#        Transition  Courant moteur de la porte  Tension moteur de la porte  \
# 39737           1                           0                           0
# 39738           2                           0                           0
# 39739           2                           0                           0
# 39740           2                           0                           0
# 39741           2                           0                           0
# 39742           2                           0                           0
# 39743           2                           0                           0
# 39744           7                           0                           0
#
#        Position moteur de la porte  Courant moteur de la marche mobile  \
# 39737                            0                                   0
# 39738                            0                                   0
# 39739                            0                                   0
# 39740                            0                                   0
# 39741                            0                                   0
# 39742                            0                                   0
# 39743                            0                                   0
# 39744                            0                                   0
#
#        Tension moteur de la marche mobile  \
# 39737                                   0
# 39738                                   0
# 39739                                   0
# 39740                                   0
# 39741                                   0
# 39742                                   0
# 39743                                   0
# 39744                                   0
#
#        Position moteur de la marche mobile  \
# 39737                                    0
# 39738                                    0
# 39739                                    0
# 39740                                    0
# 39741                                    0
# 39742                                    0
# 39743                                    0
# 39744                                    0
#
#                                                       ID  TimeStamp
# 39737  z5700015________zr_57_83015_____dcu4__________...       0.00
# 39738  z5700015________zr_57_83015_____dcu4__________...       0.05
# 39739  z5700015________zr_57_83015_____dcu4__________...      19.40
# 39740  z5700015________zr_57_83015_____dcu4__________...      22.55
# 39741  z5700015________zr_57_83015_____dcu4__________...      26.90
# 39742  z5700015________zr_57_83015_____dcu4__________...      32.80
# 39743  z5700015________zr_57_83015_____dcu4__________...      33.50
# 39744  z5700015________zr_57_83015_____dcu4__________...      33.75

# %%
i=1
p=0
s=0
d = {}
while i < len(t):
    time_t0 = datetime.strptime(t.iloc[i-1]['TimeStamp'],"%H:%M:%S")
    time_t1 = datetime.strptime(t.iloc[i]['TimeStamp'],"%H:%M:%S")
    diff = time_t1.minute - time_t0.minute
    if(diff > 1):
        echantillon = 'echantillon' + str(p)
        d[echantillon] = t.iloc[s:i]
        s=i
        i=i+1
        p=p+1
    elif(time_t1 == datetime.strptime(t.iloc[-1]['TimeStamp'],"%H:%M:%S")):
        echantillon = 'echantillon' + str(p)
        d[echantillon] = t.iloc[s:i+1]
        i=i+1
    else:
        i=i+1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-304-6d5f9f717af3> in <module>
#       4 d = {}
#       5 while i < len(t):
# ----> 6     time_t0 = datetime.strptime(t.iloc[i-1]['TimeStamp'],"%H:%M:%S")
#       7     time_t1 = datetime.strptime(t.iloc[i]['TimeStamp'],"%H:%M:%S")
#       8     diff = time_t1.minute - time_t0.minute
#
# TypeError: strptime() argument 1 must be str, not numpy.float64

# %%
i=1
p=0
s=0
d = {}
while i < len(t):
    time_t0 = t.iloc[i-1]['TimeStamp']
    time_t1 = t.iloc[i]['TimeStamp']
    diff = time_t1 - time_t0
    if(diff > 10.0):
        echantillon = 'echantillon' + str(p)
        d[echantillon] = t.iloc[s:i]
        s=i
        i=i+1
        p=p+1
    elif(time_t1 == t.iloc[-1]['TimeStamp']):
        echantillon = 'echantillon' + str(p)
        d[echantillon] = t.iloc[s:i+1]
        i=i+1
    else:
        i=i+1

# %%
n0 = d["echantillon0"]
n1 = d["echantillon1"]
n2 = d["echantillon2"]
n3 = d["echantillon3"]
n4 = d["echantillon4"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-326-71b51005046d> in <module>
#       2 n1 = d["echantillon1"]
#       3 n2 = d["echantillon2"]
# ----> 4 n3 = d["echantillon3"]
#       5 n4 = d["echantillon4"]
#
# KeyError: 'echantillon3'

# %%
#echantillon0
sns.set_style("whitegrid")
p = sns.stripplot(x="TimeStamp", y="Courant moteur de la porte", data=n0) 
plt.title("Courant moteur porte N0")
plt.show(p)
#echantillon1
sns.set_style("whitegrid")
p = sns.stripplot(x="TimeStamp", y="Courant moteur de la porte", data=n1) 
plt.title("Courant moteur porte N1")
plt.show(p)
#echantillon2
sns.set_style("whitegrid")
p = sns.stripplot(x="TimeStamp", y="Courant moteur de la porte", data=n2) 
plt.title("Courant moteur porte N2")
plt.show(p)
#echantillon3
sns.set_style("whitegrid")
p = sns.stripplot(x="TimeStamp", y="Courant moteur de la porte", data=n3) 
plt.title("Courant moteur porte N3")
plt.show(p)
#echantillon4
sns.set_style("whitegrid")
p = sns.stripplot(x="TimeStamp", y="Courant moteur de la porte", data=n4) 
plt.title("Courant moteur porte N4")
plt.show(p)

# %%
n2
# Out:
#      Transition  Courant moteur de la porte  Tension moteur de la porte  \
# 394           3                        5168                       -2100
# 395           5                        1156                       -1680
# 396           5                        1855                       -1478
# 397           5                         994                       -1716
# 398           5                          13                       -1732
# 399           5                           6                       -1810
# 400           5                           6                       -1781
# 401           5                          13                       -1433
# 402           5                         161                       -1325
# 403           5                         160                       -1428
# 404           5                         217                       -1386
# 405           5                         371                       -1470
# 406           5                         783                       -1614
# 407           5                         753                       -1500
# 408           5                         404                       -1598
# 409           5                         244                       -1573
# 410           5                         155                       -1534
# 411           5                         145                       -1556
# 412           5                         153                       -1544
# 413           5                         417                       -1597
# 414           5                         328                       -1544
# 415           5                         437                       -1642
# 416           5                         359                       -1583
# 417           5                         188                       -1596
# 418           5                         577                       -1613
# 419           5                         306                       -1631
# 420           5                         227                       -1597
# 421           5                         196                       -1585
# 422           5                         244                       -1567
# 423           5                         379                       -1586
# ..          ...                         ...                         ...
# 532           5                        1096                       -1724
# 533           5                        1514                       -1825
# 534           5                        1143                       -1767
# 535           5                         682                       -1670
# 536           5                         643                       -1721
# 537           5                        1189                       -1753
# 538           5                         765                       -1750
# 539           5                         986                       -1741
# 540           5                         978                       -1760
# 541           5                        1153                       -1765
# 542           5                        1146                       -1766
# 543           5                        2279                       -1779
# 544           5                        6194                       -2865
# 545           5                        6760                       -1864
# 546           5                        2939                          59
# 547           5                        1380                          48
# 548           5                         544                         -96
# 549           5                        1331                        -384
# 550           5                        1158                        -303
# 551           5                        1499                        -359
# 552           5                        1283                        -344
# 553           5                        1468                        -336
# 554           5                        1441                        -357
# 555           5                         974                        -277
# 556           5                         955                        -271
# 557           5                         727                        -184
# 558           5                         478                        -110
# 559           5                         232                         -27
# 560           5                           0                          35
# 561           5                           0                           0
#
#      Position moteur de la porte  Courant moteur de la marche mobile  \
# 394                          816                                   0
# 395                          810                                   0
# 396                          807                                   0
# 397                          802                                   0
# 398                          796                                   0
# 399                          789                                   0
# 400                          783                                   0
# 401                          777                                   0
# 402                          773                                   0
# 403                          768                                   0
# 404                          763                                   0
# 405                          758                                   0
# 406                          753                                   0
# 407                          748                                   0
# 408                          743                                   0
# 409                          737                                   0
# 410                          732                                   0
# 411                          726                                   0
# 412                          721                                   0
# 413                          716                                   0
# 414                          710                                   0
# 415                          705                                   0
# 416                          699                                   0
# 417                          694                                   0
# 418                          688                                   0
# 419                          683                                   0
# 420                          677                                   0
# 421                          672                                   0
# 422                          666                                   0
# 423                          661                                   0
# ..                           ...                                 ...
# 532                           61                                   0
# 533                           56                                   0
# 534                           50                                   0
# 535                           45                                   0
# 536                           39                                   0
# 537                           34                                   0
# 538                           28                                   0
# 539                           23                                   0
# 540                           17                                   0
# 541                           12                                   0
# 542                            6                                   0
# 543                            2                                   0
# 544                           -2                                   0
# 545                           -3                                   0
# 546                           -2                                   0
# 547                            0                                   0
